# %%
import cv2
import hashlib
from PIL import Image

# %% [markdown]
# # Load Image

# %%
im_path = "C:\\Users\\Shoaib\\Downloads\\baboon.png"

image = Image.open(im_path)
display(image)
size = image.size
print(size)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512 at 0x229B73A9E80>
# (512, 512)

# %% [markdown]
# # Split Image into Parts

# %%
from PIL import Image

im_path = "C:\\Users\\Shoaib\\Downloads\\baboon.png"
image = Image.open(im_path)

def split_image_into_parts(image, cols=3, rows=2):
    width, height = image.size

    width_part = width / cols
    height_part = height / rows

    parts = []
    for row in range(rows):
        for col in range(cols):
            x = col * width_part
            y = row * height_part
            w = width_part
            h = height_part

            part = image.crop((x, y, x+w, y+h))

            parts.append(part)

    return parts

#Code to Display image parts

im_parts = split_image_into_parts(image, cols=3, rows=2)
rows = 2
cols = 3
for i in range(rows):
    for j in range(cols):
        im_parts[i*cols + j].show()

# %% [markdown]
# # Joining Back of Parts

# %%
def join_image_parts(outer_list_tiles):
    # Get the size of the original image
    part_width, part_height = outer_list_tiles[0].size
    width = part_width * 3
    height = part_height * 2

    # Create a blank image to hold the joined image parts
    joined_image = Image.new(outer_list_tiles[0].mode, (width, height), (255, 255, 255, 0))

    # Paste the image parts onto the blank image
    for row in range(2):
        for col in range(3):
            part = outer_list_tiles[row * 3 + col]
            x = col * part_width
            y = row * part_height
            joined_image.paste(part, (x, y))

    return joined_image

joined_image = join_image_parts(im_parts)
display(joined_image)
# Out:
# <PIL.Image.Image image mode=RGB size=513x512 at 0x229B73AD820>

# %% [markdown]
# # Save joined Image

# %%
# your code here
joined_image.save('rejoined1_image.png')

# %% [markdown]
# # Compare Original and Saved Image Hashes (should be same)

# %%
def get_hash(file_path):
    return hashlib.md5(cv2.imread(file_path).tobytes()).hexdigest()

# Compare Hashes
print("Hash of original Image:",get_hash(im_path))
print("Hash of New Image:",get_hash(new_im_path))
# Out:
# Hash of original Image: c2be2aa5307b8a897d8c426a6dd2bd8d
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20000/2785106797.py in <module>
#       4 # Compare Hashes
#       5 print("Hash of original Image:",get_hash(im_path))
# ----> 6 print("Hash of New Image:",get_hash(new_im_path))
#
# NameError: name 'new_im_path' is not defined
